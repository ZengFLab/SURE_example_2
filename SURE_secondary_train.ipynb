# %% [markdown]
# In this file, we demonstrate the training and usage of SURE. Before running the example code in this file, please prepare the data according to the process described in the previous file.
#
# First, we use the shell to invoke commands to train the SURE model. In the following command:
# - `--data-file` is used to specify the file containing the single-cell transcriptome data. It can be a csv or tsv file, where rows represent cells and columns represent genes. Do not set row names for each row, meaning there is no need to set an index.
# - `--undesired-factor-file` is used to specify the file containing the undesired factor values. Undesired factors can be batch, sample, or any other factors that you wish to remove from the data. Users can set the undesired factors based on their actual problem requirements.
# - `--jit` is used to enable Jax acceleration. It is worth noting that if users want to use this feature, both `--data-file` and `--undesired-factor-file` need to be provided. If the user only sets `--data-file` and uses `--jit`, the program will encounter an error.
# - `-cd` is used to set the number of metacells.
# - `-lr` is the learning rate.
# - `-n` is the number of epochs.
# - `-bs` is the batch size.
# - `-zi exact` is used to specify the exact form of the zero-inflated model.
# - `-likeli negbinomial` is used to specify the negative binomial distribution model for calculating the data likelihood.

# %%
# %%bash
#
# CUDA_VISIBLE_DEVICES=0  python SURE.py --data-file "/home/oem/SURE_example_2/multiome_neurips21_secondary_counts.txt.gz" \
#                         --undesired-factor-file "/home/oem/SURE_example_2/multiome_neurips21_secondary_uwv.txt.gz" \
#                         --jit \
#                         -rt \
#                         -cd 50 \
#                         -lr 0.0001 \
#                         -n 300 \
#                         -bs 1000 \
#                         --seed 0 \
#                         --cuda \
#                         -zi exact \
#                         -likeli negbinomial \
#                         --save-model "sure_4_neurips21_secondary.pth" 2>&1 | tee "sure_4_neurips21_secondary.log"
# Out:
# /home/oem/anaconda3/envs/pyro/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# 1 epoch: avg losses 22125173.5833 elapsed 12.0330 seconds
# 2 epoch: avg losses 20970240.0000 elapsed 0.0916 seconds
# 3 epoch: avg losses 20196414.8333 elapsed 0.0918 seconds
# 4 epoch: avg losses 19647898.5000 elapsed 0.0909 seconds
# 5 epoch: avg losses 19221038.5000 elapsed 0.0911 seconds
# 6 epoch: avg losses 18847585.5833 elapsed 0.0897 seconds
# 7 epoch: avg losses 18476858.2500 elapsed 0.0899 seconds
# 8 epoch: avg losses 18203364.0000 elapsed 0.0912 seconds
# 9 epoch: avg losses 17943136.0000 elapsed 0.0914 seconds
# 10 epoch: avg losses 17719364.9167 elapsed 0.0914 seconds
# 11 epoch: avg losses 17527523.9167 elapsed 0.0910 seconds
# 12 epoch: avg losses 17346119.8333 elapsed 0.1326 seconds
# 13 epoch: avg losses 17192317.3333 elapsed 0.0908 seconds
# 14 epoch: avg losses 17048814.5833 elapsed 0.0908 seconds
# 15 epoch: avg losses 16924249.5000 elapsed 0.0910 seconds
# 16 epoch: avg losses 16813119.4167 elapsed 0.0915 seconds
# 17 epoch: avg losses 16710847.8333 elapsed 0.0914 seconds
# 18 epoch: avg losses 16619938.9167 elapsed 0.0913 seconds
# 19 epoch: avg losses 16538410.5000 elapsed 0.0912 seconds
# 20 epoch: avg losses 16465401.2500 elapsed 0.0919 seconds
# 21 epoch: avg losses 16398406.0833 elapsed 0.0908 seconds
# 22 epoch: avg losses 16342917.6667 elapsed 0.0917 seconds
# 23 epoch: avg losses 16293097.8333 elapsed 0.0917 seconds
# 24 epoch: avg losses 16249316.5833 elapsed 0.1295 seconds
# 25 epoch: avg losses 16208436.4167 elapsed 0.0891 seconds
# 26 epoch: avg losses 16171247.1667 elapsed 0.0929 seconds
# 27 epoch: avg losses 16136949.7500 elapsed 0.0902 seconds
# 28 epoch: avg losses 16105923.1667 elapsed 0.0918 seconds
# 29 epoch: avg losses 16076256.8333 elapsed 0.0959 seconds
# 30 epoch: avg losses 16049436.2500 elapsed 0.0909 seconds
# 31 epoch: avg losses 16023582.4167 elapsed 0.0921 seconds
# 32 epoch: avg losses 15999559.5000 elapsed 0.0910 seconds
# 33 epoch: avg losses 15977267.8333 elapsed 0.0893 seconds
# 34 epoch: avg losses 15956460.3333 elapsed 0.0902 seconds
# 35 epoch: avg losses 15936788.7500 elapsed 0.0928 seconds
# 36 epoch: avg losses 15918382.0000 elapsed 0.1325 seconds
# 37 epoch: avg losses 15900582.8333 elapsed 0.0912 seconds
# 38 epoch: avg losses 15883723.0000 elapsed 0.0923 seconds
# 39 epoch: avg losses 15867565.0000 elapsed 0.0915 seconds
# 40 epoch: avg losses 15852509.5833 elapsed 0.0904 seconds
# 41 epoch: avg losses 15837661.3333 elapsed 0.0922 seconds
# 42 epoch: avg losses 15824301.9167 elapsed 0.0896 seconds
# 43 epoch: avg losses 15812480.9167 elapsed 0.0925 seconds
# 44 epoch: avg losses 15800894.5833 elapsed 0.0913 seconds
# 45 epoch: avg losses 15789373.7500 elapsed 0.0912 seconds
# 46 epoch: avg losses 15778197.8333 elapsed 0.0909 seconds
# 47 epoch: avg losses 15767740.5833 elapsed 0.0909 seconds
# 48 epoch: avg losses 15757723.3333 elapsed 0.1344 seconds
# 49 epoch: avg losses 15748001.0833 elapsed 0.0910 seconds
# 50 epoch: avg losses 15737994.5833 elapsed 0.0914 seconds
# 51 epoch: avg losses 15729091.7500 elapsed 0.0917 seconds
# 52 epoch: avg losses 15719907.3333 elapsed 0.0912 seconds
# 53 epoch: avg losses 15711717.3333 elapsed 0.0916 seconds
# 54 epoch: avg losses 15703293.2500 elapsed 0.0913 seconds
# 55 epoch: avg losses 15695115.0833 elapsed 0.0910 seconds
# 56 epoch: avg losses 15686959.2500 elapsed 0.0917 seconds
# 57 epoch: avg losses 15678990.4167 elapsed 0.0912 seconds
# 58 epoch: avg losses 15671079.5000 elapsed 0.0915 seconds
# 59 epoch: avg losses 15663948.4167 elapsed 0.0910 seconds
# 60 epoch: avg losses 15656617.5000 elapsed 0.1336 seconds
# 61 epoch: avg losses 15649516.9167 elapsed 0.0897 seconds
# 62 epoch: avg losses 15642572.5000 elapsed 0.0898 seconds
# 63 epoch: avg losses 15636340.8333 elapsed 0.0892 seconds
# 64 epoch: avg losses 15630434.3333 elapsed 0.0905 seconds
# 65 epoch: avg losses 15624229.2500 elapsed 0.0896 seconds
# 66 epoch: avg losses 15618140.8333 elapsed 0.0895 seconds
# 67 epoch: avg losses 15612659.1667 elapsed 0.0894 seconds
# 68 epoch: avg losses 15606646.5000 elapsed 0.0897 seconds
# 69 epoch: avg losses 15601282.5833 elapsed 0.0899 seconds
# 70 epoch: avg losses 15595674.5000 elapsed 0.0926 seconds
# 71 epoch: avg losses 15590249.5833 elapsed 0.0912 seconds
# 72 epoch: avg losses 15584782.0000 elapsed 0.1360 seconds
# 73 epoch: avg losses 15579556.7500 elapsed 0.0913 seconds
# 74 epoch: avg losses 15574200.0833 elapsed 0.0913 seconds
# 75 epoch: avg losses 15569131.2500 elapsed 0.0910 seconds
# 76 epoch: avg losses 15563695.5000 elapsed 0.0910 seconds
# 77 epoch: avg losses 15559147.0833 elapsed 0.0920 seconds
# 78 epoch: avg losses 15553896.0833 elapsed 0.0901 seconds
# 79 epoch: avg losses 15549032.1667 elapsed 0.0925 seconds
# 80 epoch: avg losses 15544189.0000 elapsed 0.0920 seconds
# 81 epoch: avg losses 15539437.0833 elapsed 0.0911 seconds
# 82 epoch: avg losses 15535111.9167 elapsed 0.0913 seconds
# 83 epoch: avg losses 15530957.8333 elapsed 0.0913 seconds
# 84 epoch: avg losses 15527044.8333 elapsed 0.1339 seconds
# 85 epoch: avg losses 15522972.6667 elapsed 0.0909 seconds
# 86 epoch: avg losses 15518922.5000 elapsed 0.0914 seconds
# 87 epoch: avg losses 15515208.0000 elapsed 0.0911 seconds
# 88 epoch: avg losses 15511166.0000 elapsed 0.0913 seconds
# 89 epoch: avg losses 15507464.0000 elapsed 0.0912 seconds
# 90 epoch: avg losses 15503988.0000 elapsed 0.0912 seconds
# 91 epoch: avg losses 15500252.8333 elapsed 0.0909 seconds
# 92 epoch: avg losses 15496989.5833 elapsed 0.0919 seconds
# 93 epoch: avg losses 15493185.5000 elapsed 0.0910 seconds
# 94 epoch: avg losses 15489991.6667 elapsed 0.0916 seconds
# 95 epoch: avg losses 15486305.3333 elapsed 0.0910 seconds
# 96 epoch: avg losses 15483105.1667 elapsed 0.1319 seconds
# 97 epoch: avg losses 15479779.0000 elapsed 0.0907 seconds
# 98 epoch: avg losses 15476538.3333 elapsed 0.0937 seconds
# 99 epoch: avg losses 15473460.5000 elapsed 0.0915 seconds
# 100 epoch: avg losses 15470284.8333 elapsed 0.0926 seconds
# 101 epoch: avg losses 15467313.8333 elapsed 0.0911 seconds
# 102 epoch: avg losses 15463922.6667 elapsed 0.0915 seconds
# 103 epoch: avg losses 15461538.7500 elapsed 0.0914 seconds
# 104 epoch: avg losses 15459111.9167 elapsed 0.0917 seconds
# 105 epoch: avg losses 15456189.1667 elapsed 0.0917 seconds
# 106 epoch: avg losses 15453364.4167 elapsed 0.0916 seconds
# 107 epoch: avg losses 15451078.0000 elapsed 0.0910 seconds
# 108 epoch: avg losses 15448348.1667 elapsed 0.1324 seconds
# 109 epoch: avg losses 15446208.0000 elapsed 0.0904 seconds
# 110 epoch: avg losses 15443685.4167 elapsed 0.0921 seconds
# 111 epoch: avg losses 15441436.6667 elapsed 0.0914 seconds
# 112 epoch: avg losses 15439207.4167 elapsed 0.0914 seconds
# 113 epoch: avg losses 15436673.6667 elapsed 0.0915 seconds
# 114 epoch: avg losses 15434318.2500 elapsed 0.0920 seconds
# 115 epoch: avg losses 15432079.1667 elapsed 0.0914 seconds
# 116 epoch: avg losses 15429973.0000 elapsed 0.0906 seconds
# 117 epoch: avg losses 15427980.2500 elapsed 0.0915 seconds
# 118 epoch: avg losses 15425435.6667 elapsed 0.0908 seconds
# 119 epoch: avg losses 15423391.0833 elapsed 0.0915 seconds
# 120 epoch: avg losses 15421073.0000 elapsed 0.1334 seconds
# 121 epoch: avg losses 15419333.8333 elapsed 0.0920 seconds
# 122 epoch: avg losses 15417282.7500 elapsed 0.0913 seconds
# 123 epoch: avg losses 15415358.8333 elapsed 0.0909 seconds
# 124 epoch: avg losses 15413775.4167 elapsed 0.0916 seconds
# 125 epoch: avg losses 15411945.4167 elapsed 0.0915 seconds
# 126 epoch: avg losses 15409985.0000 elapsed 0.0915 seconds
# 127 epoch: avg losses 15408527.4167 elapsed 0.0913 seconds
# 128 epoch: avg losses 15406377.4167 elapsed 0.0913 seconds
# 129 epoch: avg losses 15404818.8333 elapsed 0.0916 seconds
# 130 epoch: avg losses 15403174.6667 elapsed 0.0911 seconds
# 131 epoch: avg losses 15401492.7500 elapsed 0.0912 seconds
# 132 epoch: avg losses 15399680.9167 elapsed 0.1351 seconds
# 133 epoch: avg losses 15398072.3333 elapsed 0.0896 seconds
# 134 epoch: avg losses 15396629.8333 elapsed 0.0914 seconds
# 135 epoch: avg losses 15394827.6667 elapsed 0.0921 seconds
# 136 epoch: avg losses 15393225.7500 elapsed 0.0927 seconds
# 137 epoch: avg losses 15391731.8333 elapsed 0.0912 seconds
# 138 epoch: avg losses 15390141.7500 elapsed 0.0923 seconds
# 139 epoch: avg losses 15388781.5000 elapsed 0.0912 seconds
# 140 epoch: avg losses 15387059.9167 elapsed 0.0918 seconds
# 141 epoch: avg losses 15385500.6667 elapsed 0.0916 seconds
# 142 epoch: avg losses 15384168.8333 elapsed 0.0913 seconds
# 143 epoch: avg losses 15382801.4167 elapsed 0.0920 seconds
# 144 epoch: avg losses 15381457.2500 elapsed 0.1311 seconds
# 145 epoch: avg losses 15380211.5000 elapsed 0.0911 seconds
# 146 epoch: avg losses 15379058.2500 elapsed 0.0921 seconds
# 147 epoch: avg losses 15377647.0833 elapsed 0.0910 seconds
# 148 epoch: avg losses 15376486.6667 elapsed 0.0912 seconds
# 149 epoch: avg losses 15375290.5000 elapsed 0.0916 seconds
# 150 epoch: avg losses 15373915.2500 elapsed 0.0913 seconds
# 151 epoch: avg losses 15372830.7500 elapsed 0.0910 seconds
# 152 epoch: avg losses 15371360.2500 elapsed 0.0908 seconds
# 153 epoch: avg losses 15370141.7500 elapsed 0.0923 seconds
# 154 epoch: avg losses 15368789.8333 elapsed 0.0914 seconds
# 155 epoch: avg losses 15367989.6667 elapsed 0.0913 seconds
# 156 epoch: avg losses 15366684.9167 elapsed 0.1317 seconds
# 157 epoch: avg losses 15365455.6667 elapsed 0.0915 seconds
# 158 epoch: avg losses 15364283.3333 elapsed 0.0901 seconds
# 159 epoch: avg losses 15363278.8333 elapsed 0.0911 seconds
# 160 epoch: avg losses 15361916.3333 elapsed 0.0913 seconds
# 161 epoch: avg losses 15360802.6667 elapsed 0.0922 seconds
# 162 epoch: avg losses 15359509.9167 elapsed 0.0911 seconds
# 163 epoch: avg losses 15358508.0833 elapsed 0.0910 seconds
# 164 epoch: avg losses 15357839.9167 elapsed 0.0915 seconds
# 165 epoch: avg losses 15356759.5833 elapsed 0.0916 seconds
# 166 epoch: avg losses 15355776.9167 elapsed 0.0910 seconds
# 167 epoch: avg losses 15354628.9167 elapsed 0.0910 seconds
# 168 epoch: avg losses 15353878.3333 elapsed 0.1315 seconds
# 169 epoch: avg losses 15352843.0000 elapsed 0.0905 seconds
# 170 epoch: avg losses 15351818.6667 elapsed 0.0917 seconds
# 171 epoch: avg losses 15350893.5833 elapsed 0.0908 seconds
# 172 epoch: avg losses 15349979.5833 elapsed 0.0910 seconds
# 173 epoch: avg losses 15348954.0833 elapsed 0.0912 seconds
# 174 epoch: avg losses 15348007.9167 elapsed 0.0911 seconds
# 175 epoch: avg losses 15347093.6667 elapsed 0.0912 seconds
# 176 epoch: avg losses 15346084.0000 elapsed 0.0914 seconds
# 177 epoch: avg losses 15345123.1667 elapsed 0.0911 seconds
# 178 epoch: avg losses 15344280.0000 elapsed 0.0919 seconds
# 179 epoch: avg losses 15343343.3333 elapsed 0.0913 seconds
# 180 epoch: avg losses 15342295.7500 elapsed 0.1311 seconds
# 181 epoch: avg losses 15341509.6667 elapsed 0.0903 seconds
# 182 epoch: avg losses 15340877.5833 elapsed 0.0911 seconds
# 183 epoch: avg losses 15339687.3333 elapsed 0.0905 seconds
# 184 epoch: avg losses 15339149.0000 elapsed 0.0912 seconds
# 185 epoch: avg losses 15338280.0000 elapsed 0.0917 seconds
# 186 epoch: avg losses 15337554.6667 elapsed 0.0914 seconds
# 187 epoch: avg losses 15336812.0833 elapsed 0.0908 seconds
# 188 epoch: avg losses 15335752.4167 elapsed 0.0916 seconds
# 189 epoch: avg losses 15335158.4167 elapsed 0.0921 seconds
# 190 epoch: avg losses 15334367.3333 elapsed 0.0909 seconds
# 191 epoch: avg losses 15333538.7500 elapsed 0.0913 seconds
# 192 epoch: avg losses 15332958.7500 elapsed 0.1299 seconds
# 193 epoch: avg losses 15332110.2500 elapsed 0.0907 seconds
# 194 epoch: avg losses 15331201.6667 elapsed 0.0909 seconds
# 195 epoch: avg losses 15330460.5833 elapsed 0.0919 seconds
# 196 epoch: avg losses 15329442.5833 elapsed 0.0914 seconds
# 197 epoch: avg losses 15329052.8333 elapsed 0.0910 seconds
# 198 epoch: avg losses 15328300.8333 elapsed 0.0917 seconds
# 199 epoch: avg losses 15327499.6667 elapsed 0.0914 seconds
# 200 epoch: avg losses 15326821.0833 elapsed 0.0915 seconds
# 201 epoch: avg losses 15326074.0000 elapsed 0.0915 seconds
# 202 epoch: avg losses 15325447.0000 elapsed 0.0911 seconds
# 203 epoch: avg losses 15324479.0000 elapsed 0.0908 seconds
# 204 epoch: avg losses 15323908.2500 elapsed 0.1302 seconds
# 205 epoch: avg losses 15323157.4167 elapsed 0.0897 seconds
# 206 epoch: avg losses 15322382.0000 elapsed 0.0915 seconds
# 207 epoch: avg losses 15321792.5000 elapsed 0.0907 seconds
# 208 epoch: avg losses 15321080.4167 elapsed 0.0906 seconds
# 209 epoch: avg losses 15320459.5833 elapsed 0.0910 seconds
# 210 epoch: avg losses 15319986.0000 elapsed 0.0919 seconds
# 211 epoch: avg losses 15319239.4167 elapsed 0.0905 seconds
# 212 epoch: avg losses 15318441.9167 elapsed 0.0920 seconds
# 213 epoch: avg losses 15318084.0000 elapsed 0.0907 seconds
# 214 epoch: avg losses 15317251.8333 elapsed 0.0915 seconds
# 215 epoch: avg losses 15316549.0833 elapsed 0.0907 seconds
# 216 epoch: avg losses 15315992.2500 elapsed 0.1314 seconds
# 217 epoch: avg losses 15315320.3333 elapsed 0.0900 seconds
# 218 epoch: avg losses 15314570.0000 elapsed 0.0909 seconds
# 219 epoch: avg losses 15313927.9167 elapsed 0.0909 seconds
# 220 epoch: avg losses 15313266.2500 elapsed 0.0915 seconds
# 221 epoch: avg losses 15312803.0833 elapsed 0.0919 seconds
# 222 epoch: avg losses 15312005.1667 elapsed 0.0913 seconds
# 223 epoch: avg losses 15311603.1667 elapsed 0.0912 seconds
# 224 epoch: avg losses 15311029.1667 elapsed 0.0904 seconds
# 225 epoch: avg losses 15310366.1667 elapsed 0.0922 seconds
# 226 epoch: avg losses 15309817.0000 elapsed 0.0911 seconds
# 227 epoch: avg losses 15309158.1667 elapsed 0.0909 seconds
# 228 epoch: avg losses 15308797.8333 elapsed 0.1316 seconds
# 229 epoch: avg losses 15308084.4167 elapsed 0.0903 seconds
# 230 epoch: avg losses 15307540.5833 elapsed 0.0912 seconds
# 231 epoch: avg losses 15307166.0833 elapsed 0.0920 seconds
# 232 epoch: avg losses 15306285.5000 elapsed 0.0916 seconds
# 233 epoch: avg losses 15306040.0833 elapsed 0.0915 seconds
# 234 epoch: avg losses 15305533.5000 elapsed 0.0904 seconds
# 235 epoch: avg losses 15304851.3333 elapsed 0.0915 seconds
# 236 epoch: avg losses 15304413.5833 elapsed 0.0910 seconds
# 237 epoch: avg losses 15303919.7500 elapsed 0.0909 seconds
# 238 epoch: avg losses 15303113.6667 elapsed 0.0913 seconds
# 239 epoch: avg losses 15302430.7500 elapsed 0.0909 seconds
# 240 epoch: avg losses 15302084.6667 elapsed 0.1304 seconds
# 241 epoch: avg losses 15301671.5000 elapsed 0.0910 seconds
# 242 epoch: avg losses 15301149.1667 elapsed 0.0914 seconds
# 243 epoch: avg losses 15300585.6667 elapsed 0.0913 seconds
# 244 epoch: avg losses 15300104.6667 elapsed 0.0916 seconds
# 245 epoch: avg losses 15299800.9167 elapsed 0.0912 seconds
# 246 epoch: avg losses 15299068.1667 elapsed 0.0908 seconds
# 247 epoch: avg losses 15298708.3333 elapsed 0.0908 seconds
# 248 epoch: avg losses 15298088.1667 elapsed 0.0911 seconds
# 249 epoch: avg losses 15297672.8333 elapsed 0.0915 seconds
# 250 epoch: avg losses 15297385.0833 elapsed 0.0906 seconds
# 251 epoch: avg losses 15296694.3333 elapsed 0.0912 seconds
# 252 epoch: avg losses 15296203.7500 elapsed 0.1308 seconds
# 253 epoch: avg losses 15295775.2500 elapsed 0.0913 seconds
# 254 epoch: avg losses 15295435.8333 elapsed 0.0914 seconds
# 255 epoch: avg losses 15294785.9167 elapsed 0.0914 seconds
# 256 epoch: avg losses 15294218.5000 elapsed 0.0915 seconds
# 257 epoch: avg losses 15293779.4167 elapsed 0.0912 seconds
# 258 epoch: avg losses 15293184.9167 elapsed 0.0907 seconds
# 259 epoch: avg losses 15292833.1667 elapsed 0.0912 seconds
# 260 epoch: avg losses 15292504.1667 elapsed 0.0914 seconds
# 261 epoch: avg losses 15291794.6667 elapsed 0.0912 seconds
# 262 epoch: avg losses 15291432.5833 elapsed 0.0910 seconds
# 263 epoch: avg losses 15291066.7500 elapsed 0.0911 seconds
# 264 epoch: avg losses 15290707.0833 elapsed 0.1295 seconds
# 265 epoch: avg losses 15290486.1667 elapsed 0.0913 seconds
# 266 epoch: avg losses 15289940.8333 elapsed 0.0917 seconds
# 267 epoch: avg losses 15289235.5833 elapsed 0.0920 seconds
# 268 epoch: avg losses 15288810.8333 elapsed 0.0913 seconds
# 269 epoch: avg losses 15288616.0833 elapsed 0.0918 seconds
# 270 epoch: avg losses 15288095.9167 elapsed 0.0910 seconds
# 271 epoch: avg losses 15287665.2500 elapsed 0.0915 seconds
# 272 epoch: avg losses 15287352.3333 elapsed 0.0912 seconds
# 273 epoch: avg losses 15286698.2500 elapsed 0.0914 seconds
# 274 epoch: avg losses 15286456.1667 elapsed 0.0909 seconds
# 275 epoch: avg losses 15285882.8333 elapsed 0.0910 seconds
# 276 epoch: avg losses 15285549.4167 elapsed 0.1313 seconds
# 277 epoch: avg losses 15285261.7500 elapsed 0.0907 seconds
# 278 epoch: avg losses 15284837.4167 elapsed 0.0915 seconds
# 279 epoch: avg losses 15284382.8333 elapsed 0.0907 seconds
# 280 epoch: avg losses 15283963.0000 elapsed 0.0915 seconds
# 281 epoch: avg losses 15283636.5833 elapsed 0.0912 seconds
# 282 epoch: avg losses 15283021.0000 elapsed 0.0915 seconds
# 283 epoch: avg losses 15282812.2500 elapsed 0.0914 seconds
# 284 epoch: avg losses 15282436.7500 elapsed 0.0915 seconds
# 285 epoch: avg losses 15282203.5000 elapsed 0.0904 seconds
# 286 epoch: avg losses 15281839.4167 elapsed 0.0910 seconds
# 287 epoch: avg losses 15281293.2500 elapsed 0.0907 seconds
# 288 epoch: avg losses 15280929.3333 elapsed 0.1303 seconds
# 289 epoch: avg losses 15280576.0000 elapsed 0.0899 seconds
# 290 epoch: avg losses 15280305.8333 elapsed 0.0917 seconds
# 291 epoch: avg losses 15279712.0000 elapsed 0.0910 seconds
# 292 epoch: avg losses 15279360.2500 elapsed 0.0909 seconds
# 293 epoch: avg losses 15279031.0833 elapsed 0.0913 seconds
# 294 epoch: avg losses 15278669.4167 elapsed 0.0912 seconds
# 295 epoch: avg losses 15278245.3333 elapsed 0.0912 seconds
# 296 epoch: avg losses 15277929.4583 elapsed 0.0913 seconds
# 297 epoch: avg losses 15277525.3333 elapsed 0.0909 seconds
# 298 epoch: avg losses 15277152.3333 elapsed 0.0908 seconds
# 299 epoch: avg losses 15276882.0000 elapsed 0.0908 seconds
# 300 epoch: avg losses 15276418.3333 elapsed 0.1292 seconds
# running time: 40.37424087524414 secs

# %% [markdown]
# Set up the Python environment and load some necessary packages.
#
# Here, we use R for plotting, so we need to use [rpy2](https://rpy2.github.io/). If users want to try running these R code snippets, they need to install these Python packages. If there is no need to run these R code snippets, please ignore them directly.

# %%
import numpy as np
import pandas as pd

from SURE import SURE
from utils.scdata_cached import setup_data_loader, SingleCellCached

import torch
from torch.utils.data import DataLoader

import datatable as dt


# R interface
from rpy2.robjects import pandas2ri
from rpy2.robjects import r
import rpy2.rinterface_lib.callbacks

pandas2ri.activate()

# %load_ext rpy2.ipython
# Out:
# /home/oem/anaconda3/envs/pyro/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
ModelPath = 'sure_4_neurips21_secondary.pth'
DataPath='/home/oem/SURE_example_2/multiome_neurips21_secondary_counts.txt.gz'

# %%
# load model
model = torch.load(ModelPath)

batch_size = 10000

use_float64 = False
use_cuda = True
log_trans = False

# %%
# load data
data_cached = SingleCellCached(DataPath, None, log_trans=log_trans, use_cuda=False, use_float64 = use_float64)
data_loader = DataLoader(data_cached, batch_size = batch_size, shuffle = False)

# %% [markdown]
# #### Get the latent representations of primary metacells

# %%
embeds = []
weights = []

for xs1,ks2 in data_loader:
    if use_cuda:
        xs1 = xs1.cuda()

    zs = model.get_cell_coordinates(xs1)
    ws = model.soft_assignments(xs1)
    
    if use_cuda:
        zs = zs.cpu().detach().numpy()
        ws = ws.cpu().detach().numpy()
    else:
        zs = zs.detach().numpy()
        ws = ws.detach().numpy()

    embeds.append(zs)
    weights.append(ws)

embeds = np.concatenate(embeds, axis=0)
weights = np.concatenate(weights, axis=0)


cells = pd.read_csv('/home/oem/SURE_example_2/multiome_neurips21_secondary_cell.csv.gz', header=0)
genes = pd.read_csv('/home/oem/SURE_example_2/multiome_neurips21_secondary_gene.csv.gz', header=0)

df = pd.DataFrame(embeds, index=cells.iloc[:,0].values).reset_index()
dt.Frame(df).to_csv('/home/oem/SURE_example_2/multiome_neurips21_secondary_embeds.csv.gz')

df=pd.DataFrame(weights, index=cells.iloc[:,0].values)
dt.Frame(df.reset_index()).to_csv('/home/oem/SURE_example_2/multiome_neurips21_secondary_weights.csv.gz')

# %% [markdown]
# #### Get the latent representations of secondary metacells

# %%
codebook=model.get_metacell_coordinates().cpu().detach().numpy()
pd.DataFrame(codebook).to_csv('/home/oem/SURE_example_2/multiome_neurips21_secondary_codebook.csv.gz')

# %% [markdown]
# #### Load H5AD files

# %%
import scanpy as sc

adata = sc.read_h5ad('/home/oem/SURE_example_2/multiome_neurips21_primary_metacells.h5ad')
meta = adata.obs

# %% [markdown]
# #### Invoke R to plot and display the latent representations of primary metacells and secondary metacells.

# %%
# %%R -i meta
#
# library(Seurat)
# library(dplyr)
# library(useful)
# library(data.table)
# library(ggplot2)
# library(cowplot)
# library(uwot)
#
# set.seed(123)
#
# scp <- fread('/home/oem/SURE_example_2/multiome_neurips21_secondary_embeds.csv.gz', data.table = FALSE, header = TRUE)
# rownames(scp) <- scp[,1]
# scp <- scp[,-1]
#
# embed.list <- umap(scp, n_threads = 40, pca=NULL, ret_model = TRUE)
# embed <- embed.list$embedding
# colnames(embed) <- c('UMAP_1','UMAP_2')
#
#
#
# recon <- CreateSeuratObject(scp[,1:5] %>% as.matrix %>% t, meta.data = meta[rownames(scp),])
# recon[['umap']] <- CreateDimReducObject(embed %>% as.matrix(), key = 'UMAP_')
# Out:
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# Loading required package: SeuratObject
# Loading required package: sp
# ‘SeuratObject’ was built with package ‘Matrix’ 1.6.3 but the current
# version is 1.6.5; it is recomended that you reinstall ‘SeuratObject’ as
# the ABI for ‘Matrix’ may have changed
#
# Attaching package: ‘SeuratObject’
#
# The following object is masked from ‘package:base’:
#
#     intersect
#
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: ggplot2
# data.table 1.14.10 using 6 threads (see ?getDTthreads).  Latest news: r-datatable.com
#
# Attaching package: ‘data.table’
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
# Loading required package: Matrix
# Warning: Data is of class matrix. Coercing to dgCMatrix.
# In addition: Warning messages:
# 1: In (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
#   libraries ‘/usr/local/lib/R/site-library’, ‘/usr/lib/R/site-library’ contain no packages
# 2: No assay specified, setting assay as RNA by default.

# %%
# %%R
#
# codebook <- read.csv('/home/oem/SURE_example_2/multiome_neurips21_secondary_codebook.csv.gz', row.names = 1)
# embed_cb <- umap_transform(codebook, embed.list) %>% as.data.frame()
# colnames(embed_cb) <- c('UMAP_1','UMAP_2')

# %%
# %%R -w 800 -h 500 -u px
#
# plt <- DimPlot(recon, reduction = 'umap', group.by = 'cell_type', label=TRUE, repel=TRUE)
# plt + geom_point(data = embed_cb, aes(UMAP_1,UMAP_2), size=1)
